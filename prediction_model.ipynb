# %%
import pandas as pd
import numpy as np

# %%
## load data
ai_training = pd.read_csv('train.csv')  # training set
ai_testing = pd.read_csv('test.csv')    # testing set

ai_training.head()
# Out:
#    ID  Age  AI_Interaction_Level  Satisfaction_with_AI_Services  \
# 0   1   59                     2                              7
# 1   2   49                     2                              6
# 2   3   35                     2                              3
# 3   4   63                     2                              3
# 4   5   28                     4                              6
#
#    AI_Personalization_Effectiveness  AI_Response_Time  \
# 0                                 7                 2
# 1                                 5                 1
# 2                                 3                 3
# 3                                 3                 2
# 4                                 6                 1
#
#    Overall_Usage_Frequency  Customer_Service_Interactions  \
# 0                       18                              5
# 1                        3                              2
# 2                        8                              2
# ...
